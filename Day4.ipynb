# %% [markdown]
# # Day 4 Classification Tasks

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Decision Trees
#
# - [Predicint ICU Death](./notebooks/DecisionTree_MIMI34MD.ipynb)

# %%
YouTubeVideo("Z5d-VE8TUzk")

# %% [markdown]
# ## Naive Bayes
#
# - [Gaussian NB background](./notebooks/05.05-Naive-Bayes.ipynb)
